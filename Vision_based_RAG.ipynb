# %% [markdown]
# ## Setup

# %%
# !pip install byaldi claudette
# !sudo apt-get install -y poppler-utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.9/517.9 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.9/891.9 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git qwen-vl-utils flash-attn optimum auto-gptq bitsandbytes
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 72.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 111.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata

# %%
import base64
import os
os.environ["HF_TOKEN"] = 'YOUR_HF_TOKEN'
from byaldi import RAGMultiModalModel
from claudette import *

# %%
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2", verbose=1)
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# adapter_config.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/862M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/78.6M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# ...

# %%
# Provide the PDF URL 

# !wget https://arxiv.org/pdf/1706.03762
# !mkdir docs
# !mv 1706.03762 docs/attention.pdf
# Out:
# --2024-09-07 03:41:55--  https://arxiv.org/pdf/1706.03762
# Resolving arxiv.org (arxiv.org)... 151.101.67.42, 151.101.195.42, 151.101.3.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.67.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2215244 (2.1M) [application/pdf]
# Saving to: ‘1706.03762’
#
# 1706.03762          100%[===================>]   2.11M  --.-KB/s    in 0.009s
#
# 2024-09-07 03:41:55 (227 MB/s) - ‘1706.03762’ saved [2215244/2215244]

# %% [markdown]
# ### Indexing

# %%
# Or Just Upload a PDF and give the path in input_path

RAG.index(
    input_path="/content/ELGi-High-Pressure-Compressors.pdf",
    index_name="attention",
    store_collection_with_index=True, # set this to false if you don't want to store the base64 representation
    overwrite=True
)
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Added page 1 of document 0 to index.
# Added page 2 of document 0 to index.
# Added page 3 of document 0 to index.
# Added page 4 of document 0 to index.
# Added page 5 of document 0 to index.
# Added page 6 of document 0 to index.
# Index exported to .byaldi/attention
# Index exported to .byaldi/attention
# {0: '/content/ELGi-High-Pressure-Compressors.pdf'}

# %%
RAG.index
# Out:
# <bound method RAGMultiModalModel.index of <byaldi.RAGModel.RAGMultiModalModel object at 0x7a2076212440>>

# %% [markdown]
# ### Query time

# %%
query = "free air delivery TS 15 L B PET "

# %%
results = RAG.search(query, k=1)

# %%
results
# Out:
# [{'doc_id': 0, 'page_num': 5, 'score': 17.625, 'metadata': {}, 'base64': '...'}]

# %% [markdown]
# ### Actual image data

# %%
image_bytes = base64.b64decode(results[0].base64)

# %%
filename = 'image.jpg'  # I assume you have a JPG file
with open(filename, 'wb') as f:
  f.write(image_bytes)

# %%
from IPython.display import Image

display(Image(filename))

import os
import google.generativeai as genai

genai.configure(api_key='AIzaSyBlozhatVPqJP9H56dYXXceVO6-L7r47gw')

myfile = genai.upload_file("/content/image.jpg")
print(f"{myfile=}")

model = genai.GenerativeModel("gemini-1.5-flash")
result = model.generate_content(
    [myfile, "\n\n", query]
)
print(f"{result.text=}")
# Out:
# myfile=genai.File({
#     'name': 'files/dtu5yqigvfty',
#     'display_name': 'image.jpg',
#     'mime_type': 'image/jpeg',
#     'sha256_hash': 'ODg2YTM1Yzg2MTE0YTViOTg2ZWJmMWY1NGE4YjQ1ZDQyZTYxOWU1YWYxYjBmMWU4NzAyNDIxZGVjZWJjOTNhZg==',
#     'size_bytes': '744050',
#     'state': 'ACTIVE',
#     'uri': 'https://generativelanguage.googleapis.com/v1beta/files/dtu5yqigvfty',
#     'create_time': '2024-09-10T10:31:01.351515Z',
#     'expiration_time': '2024-09-12T10:31:01.282800081Z',
#     'update_time': '2024-09-10T10:31:01.351515Z'})
# result.text='The free air delivery of the TS 15 L B PET is 30 cfm.'
